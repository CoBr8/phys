# %% [markdown]
# # Extract and write surface properties from 20$M_\odot$ stellar evolution model

# %% [markdown]
# ## Initialize session

# %%
# %pylab 
from nugridpy import nugridse as mp
from nugridpy import mesa as ms

# default data location (try mirror if default
# is not available)
#data_dir="/tmp/nugrid_data"   

# mirror data locations (some mirrors 
# may not be available at some time)

# data_dir="/data/nugrid_cedar"  # may be default    
data_dir="/data/nugrid_rpod4"    
# data_dir="/data/nugrid_vos"    


ms.set_nugrid_path(data_dir)
mp.set_nugrid_path(data_dir)
# Out:
# Using matplotlib backend: nbAgg
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## The MESA stellar evolution model
# Initialise the 20 solar-mass Z=0.02 MESA stellar evolution model:

# %%
s=ms.star_log(mass=20,Z=0.02)
# Out:
# nugrid_path = /data/nugrid_rpod4
# closest set is set1.2 (Z = 0.02)
# closest mass is 20.0
# Using old star.logsa file ...
#  reading ...100%

# %% [markdown]
# What's happening at the surface of the star? ...

# %%
ifig=102;close(ifig);figure(ifig)
s.hrd_new()
legend(loc='lower right').draw_frame(False)
# Out:
# <img src="data:image/png;base64,..." width="852.75">

# %%
# these are the available columns
# s.cols

# %%
things=['star_age','log_L','log_Teff','log_R','log_g']
writedata=[]
for thing in things:
    writedata.append(s.get(thing))
writedata = array(writedata)

# %%
savetxt('M20star-surface.dat', writedata.T,header='20Msun surface properties as a function of time; \
\nCreated with notebook "20Msun-surfacedata.ipynb" on \nNuGrid server http://wendi1.phys.uvic.ca\n\
Cols:   star_age [yr], log_L [log10 L/Lsun],    log_Teff [log10 T/K],    log_R [log10 R/Rsun],    log_g [log g [cgs]]')

# %%
! head M20star-surface.dat
# Out:
# # 20Msun surface properties as a function of time;
# # Created with notebook "20Msun-surfacedata.ipynb" on
# # NuGrid server http://wendi1.phys.uvic.ca
# # Cols:   star_age [yr], log_L [log10 L/Lsun],    log_Teff [log10 T/K],    log_R [log10 R/Rsun],    log_g [log g [cgs]]
# 6.250000000000001682e-11 4.190689950571043099e+00 3.502630060967596215e+00 2.613343689802956948e+00 5.122319694711924276e-01
# 1.125000000000000122e-10 4.201859950931701171e+00 3.505438802160207867e+00 2.613311207598062680e+00 5.122969338809815198e-01
# 1.632832422125913382e-10 4.201845966017196510e+00 3.505434574592834807e+00 2.613312670275556027e+00 5.122940085259944931e-01
# 2.242231328677009345e-10 4.201830559252612396e+00 3.505431514088626965e+00 2.613311087901679652e+00 5.122971732737475747e-01
# 2.973510016538324708e-10 4.201817920746989010e+00 3.505428314856145811e+00 2.613311167113830269e+00 5.122970148494456755e-01
# ...
